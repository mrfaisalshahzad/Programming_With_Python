# %%
# While Loops

i = 0
while i < 3:
    print("meow")
    i += 1
    print(i)

# %%
# For Loops

for i in [0, 1, 2]:
    print("meow")
    print(i)

# %%
for i in range(3):
    print("meow")
    print(i)
