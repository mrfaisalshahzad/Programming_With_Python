# %%
# a simple print function

print("Hello, World!")

# %%
# using variables to store values
# "=" is the assignment operator
# "+" is the concatenation operator
# "hello" is a string
# below print function has 2 arguments, the first one is a string and the second one is a variable


name = input("What's your name? ")
print("hello, " + name)

# %%
# print function syntex: print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
# explanation of the print function syntex:
# *objects: the objects to be printed, separated by sep
# sep: the separator between the objects, default is a space
# end: the string appended after the last object, default is a newline
# file: the file to write the output to, default is sys.stdout
# flush: whether to forcibly flush the stream, default is False

# objects, sep and end are also called named peramaters, they can be used in any order and they can be omitted if they are not needed


name = input("What's your name? ")
print("hello", name, sep=" ", end=", ")
print("welcome to the world of programming with python!")

# %%
name = input("What's your name? ")
print('hello, "Faisal"')
print("hello, \"faisal\"")

# f-string is a string literal that is prefixed with 'f' or 'F' and contains expressions inside curly braces {} that are evaluated at runtime and formatted using the __format__ protocol
# f-string is a format string

print(f"hello, {name}")

# %%
name = input("what's your name? ")
print("hello, " , name)

# Remove whitespace from the beginning and end of the string
# Where .strip() is a method that removes any leading and trailing whitespace from a string. It does not modify the original string, but returns a new string with the whitespace removed.
name = name.strip()

# Capitalize the first letter of the string and make the rest of the letters lowercase
name = name.capitalize().title()

# name = input("what's your name? ").strip().capitalize().title() is the same as the above code but in one line

# Split user's name into first name and last name
first, last = name.split(" ")
print(f"hello, {first}")

print("hello," , name)
print(name)

# %%
# types of numbers in python:
# int (integer)
# float (floating point)
# complex (complex numbers)

# Number symbols and their meanings:
# + : addition
# - : subtraction
# * : multiplication
# / : division
# // : floor division
# % : modulus
# ** : exponentiation

# Lets create a Calculator

# x = input("What's x? ")
# y = input("What's y? ")
# z = int(x) + int(y)
# print(z)

# More concise way to write the above code is:

x = int(input("What's x? "))
y = int(input("What's y? "))
print(x + y)

# %%
x = float(input("What's x? "))
y = float(input("What's y? "))
print(x + y)

# %%
# Round function
# round function looks like this: round(number[, ndigits])

x = float(input("What's x? "))
y = float(input("What's y? "))
z = round(x + y)
print(z)

# %%
# Using thousands separator in the print function

x = float(input("What's x? "))
y = float(input("What's y? "))
z = round(x + y)
print(f"{z:,}")

# %%
x = float(input("What's x? "))
y = float(input("What's y? "))
z = x / y
print(z)

# %%
x = float(input("What's x? "))
y = float(input("What's y? "))
z = round(x / y, 2)
print(z)
print(f"{z:.4f}")

# %%
# Functions
# def is a keyword that is used to define a function in python. A function is a block of code that performs a specific task. It can take input in the form of parameters and can return output.
# Functions are reusable and can be called multiple times in a program. They help to break down a program into smaller, manageable pieces and make the code more organized and readable.

def hello(to="world"):
    print("hello", to)

hello()
name = input("What's your name? ")
hello(name)

# %%
# This is not a correct way to write the code because the hello function is defined after it is called. The hello function should be defined before it is called.


hello()
name = input("What's your name? ")
hello(name)










def hello(to="world"):
    print("hello", to)

# %%
# Main part of the code should be at the top of your file.

def main():
    name = input("What's your name? ")
    print("hello", name)

def hello(to="world"):
    print("hello", to)

# hello()
main()

# %%
# This is not the correct way

# Delete the variable name from the memory first and then try to access it in the hello function. This will raise a NameError because the variable name is not defined in the hello function.
# del name

def main():
    name = input("What's your name? ")
    hello()

def hello():
    print("hello", name)


main()

# %%
# How to return the value from a function

def main():
    x = int(input("What's x? "))
    print("x squared is", square(x))

def square(n):
    # return n * n is the same as return n ** 2
    # return n ** 2 is the same as return pow(n, 2)
    return pow(n, 2)

main()

# %%
def area(length, width):
    print(str(length * width) + " square feet")

def main():
    area(50, 20)
    area(50, 50)

main()

# %%
def area(length, width):
    print(str(length * width) + " square feet")
    return length * width
    print(str(length * width) + " square feet") # this line will never be executed because the function will return before it reaches this line

def main():
    house = area(50, 20)
    garden = area(50, 50)
    total = house + garden
    print(f"Total area is {total:,} square feet")

main()
# Out:
# 1000 square feet
# 2500 square feet
# Total area is 3,500 square feet

# %%
# Variable

time = "7:00 PM"
timezone = "US/Eastern"

time = "8:00 PM"
timezone = "US/Central"

print(time + " in " + timezone)

# %%
# Side effects of a function is when a function modifies a variable that is outside of its scope. This can lead to unexpected behavior and bugs in the code.

emoticon = "v.v"


def main():
    global emoticon
    say("is anyone there?")
    emoticon = ":D"
    say("Oh, hi!")

def say(phrase):
    print(phrase + " " + emoticon)


main()
# Out:
# is anyone there? v.v
# Oh, hi! :D

# %%
# Strings methods are built-in functions that can be called on string objects to perform various operations on them. Some common string methods include:
# .strip() - removes any leading and trailing whitespace from a string
# .capitalize() - capitalizes the first letter of a string and makes the rest of the letters lowercase
# .title() - capitalizes the first letter of each word in a string

SHOWS = [" stranger things ", "the Crown", "The witcher", "money heist", "narcos ", "  The Mandalorian ", "The Boys"]

def main():
    for show in SHOWS:
        print(show.strip().title())
        
main()
# Out:
# Stranger Things
# The Crown
# The Witcher
# Money Heist
# Narcos
# The Mandalorian
# The Boys

# %%
SHOWS = [" stranger things ", "the Crown", "The witcher", "money heist", "narcos ", "  The Mandalorian ", "The Boys"]

def main():
    cleaned_shows = []
    for show in SHOWS:
        cleaned_shows.append(show.strip().title())
    print(','.join(cleaned_shows))

main()
# Out:
# Stranger Things,The Crown,The Witcher,Money Heist,Narcos,The Mandalorian,The Boys

# %%
# implement a program in Python that prompts the user for input and then outputs that same input, replacing each space with ... (i.e., three periods).
user_input = input("Enter some text: ")
print(user_input.replace(" ", "..."))
# Out:
# This...is...CS50

# %%
emoticon = ":)"

def convert():
    global emoticon
    emoticon = "🙂"
    say("Hi, how are you?")
    emoticon = "🙁"
    say("I'm sick today")


def say(phrase):
    print(phrase + " "  + emoticon)

convert()
# Out:
# Hi, how are you? 🙂
# I'm sick today 🙁

# %%
# implement a function called convert that accepts a str as input and returns that same input with any :) converted to 🙂 (otherwise known as a slightly smiling face) and any :( converted to 🙁 (otherwise known as a slightly frowning face). All other text should be returned unchanged.

# Then, in that same file, implement a function called main that prompts the user for input, calls convert on that input, and prints the result. You’re welcome, but not required, to prompt the user explicitly, as by passing a str of your own as an argument to input. Be sure to call main at the bottom of your file.

def main():
    user_input = input("Enter a string: ")
    print(convert(user_input))

def convert(input_str):
    return input_str.replace(":)", "🙂").replace(":(", "🙁")

main()
# Out:
# Hello 🙂 Goodbye 🙁

# %%
m = int(input("What's m? "))
c = 300000000
e = (m * pow(c, 2))
print(e)
# Out:
# 450000000000000000000

# %%
def main():
    dollars = dollars_to_float(input("How much was the meal? "))
    percent = percent_to_float(input("What percentage would you like to tip? "))
    tip = dollars * percent
    print(f"Leave ${tip:.2f}")


def dollars_to_float(d):
    return float(d.replace("$", ""))


def percent_to_float(p):
    return float(p.replace("%", "")) / 100


main()
# Out:
# Leave $15.00
